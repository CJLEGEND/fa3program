# %% [markdown]
# <a href="https://colab.research.google.com/github/CJLEGEND/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = (input("Enter your name: "))
age = int(input("Enter your age: "))
course = (input("Enter your course: "))

print("Your name is:",name)
print("Your age is:",age)
print("Your course is:",course)
# Out:
# Enter your name: Cejian
# Enter your age: 90
# Enter your course: Computer Science
# Your name is: Cejian
# Your age is: 90
# Your course is: Computer Science

# %%
score = int(input("Enter your score: "))

if score >= 75:
  print("You passed the exam! ")
else:("You have failed the exam. ")
# Out:
# Enter your score: 90
# You passed the exam!

# %%
name = (input("Enter your name: "))
score = int(input("Enter your score:"))

if score >= 90 and 100:
  print ("Your grade is: A")
elif score >= 80 and 89:
  print ("Your grade is: B")
elif score >= 70 and 79:
  print ("Your grade is: C")
else:
  print ("Your grade is: F")
# Out:
# Enter your name: Cejian
# Enter your score:69
# Your grade is: F
